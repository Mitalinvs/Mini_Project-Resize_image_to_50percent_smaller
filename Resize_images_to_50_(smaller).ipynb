# %% [markdown]
# <a href="https://colab.research.google.com/github/Mitalinvs/Mini_Project-Resize_image_to_50percent_smaller/blob/main/Resize_images_to_50_(smaller).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow

img = cv2.imread('/content/Colourful.png', cv2.IMREAD_UNCHANGED)
print('Original Dimensions : ',img.shape)
cv2_imshow(img)

scale_percent = 50 # percent of original size
width = int(img.shape[1] * scale_percent / 100)
height = int(img.shape[0] * scale_percent / 100)
dim = (width, height)

# resize image
resized = cv2.resize(img, dim, interpolation = cv2.INTER_AREA)
print('Resized Dimensions : ',resized.shape)
cv2_imshow(resized)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# Original Dimensions :  (398, 732, 4)
# <PIL.Image.Image image mode=RGBA size=732x398 at 0x7FA5BCEAFD60>
# Resized Dimensions :  (199, 366, 4)
# <PIL.Image.Image image mode=RGBA size=366x199 at 0x7FA5BCEAFD30>
